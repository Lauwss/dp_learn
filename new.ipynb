# %%
import h5py
path=r'C:\Users\Administrator\Desktop\dp_learn\plt_1.h5'
file=h5py.File(path,'r')

# %%
print(file.keys())
dataset=file['time']
print(dataset)
# Out:
# <KeysViewHDF5 ['diameter', 'dir', 'mach', 'pressure', 'temperature_gas', 'time', 'volume_fraction_coal', 'xVel_gas', 'yVel_gas']>
# <HDF5 dataset "time": shape (305,), type "<f8">
